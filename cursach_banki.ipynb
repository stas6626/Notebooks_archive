# %%
from sklearn import ensemble , cross_validation, learning_curve, metrics, preprocessing,tree,neural_network

import numpy as np
import pandas as pd
import xgboost as xgb

# %%
data=pd.read_csv("/home/stas/data/mushrooms.csv")

# %%
X=data.iloc[:,1:]

# %%
y=data.iloc[:,0]

# %%
y_new=np.ones(8124)

# %%
bank
# Out:
#       age            job   marital  education default  balance housing loan  \
# 0      30     unemployed   married    primary      no     1787      no   no
# 1      33       services   married  secondary      no     4789     yes  yes
# 2      35     management    single   tertiary      no     1350     yes   no
# 3      30     management   married   tertiary      no     1476     yes  yes
# 4      59    blue-collar   married  secondary      no        0     yes   no
# 5      35     management    single   tertiary      no      747      no   no
# 6      36  self-employed   married   tertiary      no      307     yes   no
# 7      39     technician   married  secondary      no      147     yes   no
# 8      41   entrepreneur   married   tertiary      no      221     yes   no
# 9      43       services   married    primary      no      -88     yes  yes
# 10     39       services   married  secondary      no     9374     yes   no
# ...

# %%
for i in range(0,len(y)):
    if y[i]=="e":
        y_new[i]=0

# %%
estimator = xgb.XGBClassifier(learning_rate=0.01, max_depth=1000, n_estimators=1000, min_child_weight=3)

# %%
enc = preprocessing.OneHotEncoder()

# %%
bank=pd.read_csv("/home/stas/data/bank.csv",sep=";")

# %%
bank
# Out:
#       age            job   marital  education default  balance housing loan  \
# 0      30     unemployed   married    primary      no     1787      no   no
# 1      33       services   married  secondary      no     4789     yes  yes
# 2      35     management    single   tertiary      no     1350     yes   no
# 3      30     management   married   tertiary      no     1476     yes  yes
# 4      59    blue-collar   married  secondary      no        0     yes   no
# 5      35     management    single   tertiary      no      747      no   no
# 6      36  self-employed   married   tertiary      no      307     yes   no
# 7      39     technician   married  secondary      no      147     yes   no
# 8      41   entrepreneur   married   tertiary      no      221     yes   no
# 9      43       services   married    primary      no      -88     yes  yes
# 10     39       services   married  secondary      no     9374     yes   no
# ...

# %%
le = preprocessing.LabelEncoder()

# %%
le.fit(bank['job'])
# Out:
# LabelEncoder()

# %%
le.transform(bank['job'])
# Out:
# array([10,  7,  4, ...,  9,  1,  2])

# %%
bank_vords=bank.iloc[:,[1,2,3,4,6,7,8,10,15,16]]
bank_numeric=bank.iloc[:,[0,5,9,11,12,13,14]]

# %%
X=[]
for i in range(0,10):
    X.append(le.fit_transform(bank_vords.iloc[:,[i]]))

# %%
X1=[]
for i in range(0,7):
    X1.append(np.array(bank_numeric.iloc[:,[i]]))

# %% [markdown]
# np.array(X1)

# %%
y=X[9]

# %%
X=X[:9]

# %%
len(X)
# Out:
# 9

# %%
X=np.array(X)

# %%
X1
# Out:
# [      age
#  0      30
#  1      33
#  2      35
#  3      30
#  4      59
#  5      35
#  6      36
#  7      39
#  8      41
#  9      43
#  10     39
#  11     43
#  12     36
#  13     20
#  14     31
#  15     40
#  16     56
#  17     37
#  18     25
#  19     31
#  20     38
#  21     42
#  22     44
#  23     44
#  24     26
#  25     41
#  26     55
#  27     67
#  28     56
#  29     53
#  ...   ...
#  4491   35
#  4492   32
#  4493   28
#  4494   26
#  4495   48
#  4496   30
#  4497   31
#  4498   31
#  4499   45
#  4500   38
#  4501   34
#  4502   42
#  4503   60
#  4504   42
#  4505   32
#  4506   42
#  4507   33
#  4508   42
#  4509   51
#  4510   36
#  4511   46
#  4512   40
#  4513   49
#  4514   38
#  4515   32
#  4516   33
#  4517   57
#  4518   57
#  4519   28
#  4520   44
#
#  [4521 rows x 1 columns],       balance
#  0        1787
#  1        4789
#  2        1350
#  3        1476
#  4           0
#  5         747
#  6         307
#  7         147
# ...

# %%
# %%time
score1.append(cross_validation.cross_val_score(estimator, X.T, y,scoring = 'accuracy', cv = 3))
# Out:
# CPU times: user 900 ms, sys: 12 ms, total: 912 ms
# Wall time: 280 ms

# %%
score1=[]

# %%
score1
# Out:
# [array([ 0.88992042,  0.88453882,  0.89243028]),
#  array([ 0.88992042,  0.88453882,  0.89243028]),
#  array([ 0.89171271,  0.88274336,  0.8949115 ,  0.8960177 ,  0.90597345]),
#  array([ 0.89171271,  0.88274336,  0.8949115 ,  0.8960177 ,  0.90597345]),
#  array([ 0.89171271,  0.88274336,  0.8949115 ,  0.8960177 ,  0.90597345]),
#  array([ 0.88741722,  0.90265487,  0.87389381,  0.90707965,  0.89159292,
#          0.89823009,  0.89159292,  0.9159292 ,  0.90707965,  0.90486726]),
#  array([ 0.89834254,  0.89269912,  0.89269912,  0.89712389,  0.8960177 ]),
#  array([ 0.88992042,  0.88453882,  0.89243028])]

# %%
len(X.T)
# Out:
# 4521

# %%
len(X1.T)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-e2df049a6bc2> in <module>()
# ----> 1 len(X1.T)
#
# AttributeError: 'list' object has no attribute 'T'

# %%
X1=np.ones((7,4521),dtype="float64")
for i in range(0,7):
    X1[i]=np.array(bank_numeric.iloc[:,[i]]).T

# %%
X1=np.array(X1)

# %%
new_X=np.hstack((X.T,X1.T))

# %%
# %%time
score1.append(cross_validation.cross_val_score(estimator, new_X, y,scoring = 'accuracy', cv = 10))
# Out:
# CPU times: user 5.13 s, sys: 24 ms, total: 5.15 s
# Wall time: 1.36 s

# %%
score2=[]

# %%
score1[5].mean()
# Out:
# 0.89803375725253465

# %%
tree_clf=ensemble.RandomForestClassifier(n_estimators=500,max_depth=4000)

# %%
# %%time
score2.append(cross_validation.cross_val_score(tree_clf, new_X, y,scoring = 'accuracy', cv = 5))
# Out:
# Exception ignored in: <bound method DMatrix.__del__ of <xgboost.core.DMatrix object at 0x7f285b4100f0>>
# Traceback (most recent call last):
#   File "/home/stas/anaconda3/lib/python3.6/site-packages/xgboost/core.py", line 324, in __del__
#     _check_call(_LIB.XGDMatrixFree(self.handle))
# AttributeError: 'DMatrix' object has no attribute 'handle'
# CPU times: user 16.2 s, sys: 128 ms, total: 16.3 s
# Wall time: 16.3 s

# %%
score2[1].mean()
# Out:
# 0.89758812888084871

# %%
score1
# Out:
# [array([ 0.88992042,  0.88453882,  0.89243028]),
#  array([ 0.88992042,  0.88453882,  0.89243028]),
#  array([ 0.89171271,  0.88274336,  0.8949115 ,  0.8960177 ,  0.90597345]),
#  array([ 0.89171271,  0.88274336,  0.8949115 ,  0.8960177 ,  0.90597345]),
#  array([ 0.89171271,  0.88274336,  0.8949115 ,  0.8960177 ,  0.90597345]),
#  array([ 0.88741722,  0.90265487,  0.87389381,  0.90707965,  0.89159292,
#          0.89823009,  0.89159292,  0.9159292 ,  0.90707965,  0.90486726]),
#  array([ 0.89834254,  0.89269912,  0.89269912,  0.89712389,  0.8960177 ]),
#  array([ 0.88992042,  0.88453882,  0.89243028]),
#  array([ 0.88741722,  0.90265487,  0.87389381,  0.90707965,  0.89159292,
#          0.89823009,  0.89159292,  0.9159292 ,  0.90707965,  0.90486726])]

# %%
estimator.fit(new_X,y)
# Out:
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=1,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=5,
#        min_child_weight=3, missing=None, n_estimators=50, nthread=-1,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=1)

# %%
estimator.feature_importances_
# Out:
# array([ 0.0387931 ,  0.02047414,  0.02155172,  0.00107759,  0.03340517,
#         0.01400862,  0.04956897,  0.11099138,  0.03556034,  0.11530172,
#         0.12068965,  0.08297414,  0.24676724,  0.02586207,  0.06573276,
#         0.01724138], dtype=float32)

# %%
neur=neural_network.MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(20, 5), random_state=1)

# %%
# %%time
score1.append(cross_validation.cross_val_score(neur, new_X, y,scoring = 'accuracy', cv = 5))
# Out:
# CPU times: user 5.38 s, sys: 56 ms, total: 5.44 s
# Wall time: 2.73 s

# %%
score1
# Out:
# [array([ 0.88992042,  0.88453882,  0.89243028]),
#  array([ 0.88992042,  0.88453882,  0.89243028]),
#  array([ 0.89171271,  0.88274336,  0.8949115 ,  0.8960177 ,  0.90597345]),
#  array([ 0.89171271,  0.88274336,  0.8949115 ,  0.8960177 ,  0.90597345]),
#  array([ 0.89171271,  0.88274336,  0.8949115 ,  0.8960177 ,  0.90597345]),
#  array([ 0.88741722,  0.90265487,  0.87389381,  0.90707965,  0.89159292,
#          0.89823009,  0.89159292,  0.9159292 ,  0.90707965,  0.90486726]),
#  array([ 0.89834254,  0.89269912,  0.89269912,  0.89712389,  0.8960177 ]),
#  array([ 0.88992042,  0.88453882,  0.89243028]),
#  array([ 0.88741722,  0.90265487,  0.87389381,  0.90707965,  0.89159292,
#          0.89823009,  0.89159292,  0.9159292 ,  0.90707965,  0.90486726]),
#  array([ 0.8839779 ,  0.88495575,  0.88495575,  0.88495575,  0.88495575]),
#  array([ 0.8839779 ,  0.88495575,  0.88495575,  0.88495575,  0.88495575])]

# %%
poly=preprocessing.PolynomialFeatures(2)

# %%
fucking_new_X=poly.fit_transform(new_X)

# %%
len(fucking_new_X.T)
# Out:
# 153

# %%
# %%time
score1.append(cross_validation.cross_val_score(estimator, fucking_new_X, y,scoring = 'accuracy', cv = 5))
# Out:
# CPU times: user 16 s, sys: 128 ms, total: 16.1 s
# Wall time: 4.26 s

# %%
# %%time
score1.append(cross_validation.cross_val_score(tree_clf, fucking_new_X, y,scoring = 'accuracy', cv = 5))
# Out:
# CPU times: user 40.7 s, sys: 76 ms, total: 40.7 s
# Wall time: 40.7 s

# %%
score1[12].mean()-score1[11].mean()
# Out:
# 0.0030956338923385784
